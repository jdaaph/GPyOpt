# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2

from GPyOpt.methods import BayesianOptimization
import GPy
import GPyOpt
from numpy.random import seed
from tqdm import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# WARNING: pylab import has clobbered these variables: ['__version__']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
def myf(x):
    return -((x>0)*2-1)

bounds = [{'name': 'var_1', 'type': 'continuous', 'domain': (-100,100)}]
max_iter = 15

# %%
myProblem = BayesianOptimization(myf,bounds,acquisition_type="BinaryT",
#                                  initial_design_numdata=None,
                                 normalize_Y = True,
                                 batch_size = 2,
                                 evaluator_type='local_penalization')
# Out:
# <GPyOpt.acquisitions.LP.AcquisitionLP object at 0x117469588>
# r
# [  1.21807742e-11]

# %%
from IPython.display import clear_output
myProblem.plot_acquisition()

for i in tqdm(range(15)):
    myProblem.run_optimization(max_iter=1) 
    myProblem.plot_acquisition_binaryT()
# Out:
# [[-19.3551747 ]
#  [-10.54725743]
#  [ 12.22261703]
#  [-88.68964243]
#  [ 80.77295272]]
#   0%|          | 0/15 [00:00<?, ?it/s]
# r
# [  3.31884058e-12]
# r
# [  4.29138918e-12]
# [[-19.3551747 ]
#  [-10.54725743]
#  [ 12.22261703]
#  [-88.68964243]
#  [ 80.77295272]
#  [ -1.19498703]
#  [-52.75270934]]
#   7%|▋         | 1/15 [00:01<00:25,  1.85s/it]
# r
# [  4.29138919e-12]
# r
# [ 0.69636207]
# [[-19.3551747 ]
#  [-10.54725743]
#  [ 12.22261703]
#  [-88.68964243]
#  [ 80.77295272]
#  [ -1.19498703]
#  [-52.75270934]
#  [  3.10801744]
#  [ 48.10364992]]
#  13%|█▎        | 2/15 [00:03<00:23,  1.83s/it]
# r
# [ 0.69636207]
# r
# [ 1.21126604]
# [[ -19.3551747 ]
#  [ -10.54725743]
#  [  12.22261703]
#  [ -88.68964243]
#  [  80.77295272]
#  [  -1.19498703]
#  [ -52.75270934]
#  [   3.10801744]
#  [  48.10364992]
#  [ 100.        ]
#  [  27.59832919]]
#  20%|██        | 3/15 [00:05<00:21,  1.80s/it]
# r
# [ 1.21126604]
# r
# [ 1.31192246]
# [[ -19.3551747 ]
#  [ -10.54725743]
#  [  12.22261703]
#  [ -88.68964243]
#  [  80.77295272]
#  [  -1.19498703]
#  [ -52.75270934]
#  [   3.10801744]
#  [  48.10364992]
#  [ 100.        ]
#  [  27.59832919]
#  [  64.4581032 ]
#  [-100.        ]]
#  27%|██▋       | 4/15 [00:07<00:20,  1.83s/it]
# r
# [ 1.31192246]
# r
# [ 1.31455741]
# [[ -19.3551747 ]
#  [ -10.54725743]
#  [  12.22261703]
#  [ -88.68964243]
#  [  80.77295272]
#  [  -1.19498703]
#  [ -52.75270934]
#  [   3.10801744]
#  [  48.10364992]
#  [ 100.        ]
#  [  27.59832919]
#  [  64.4581032 ]
#  [-100.        ]
#  [ -71.01386807]
#  [ -66.42034859]]
#  33%|███▎      | 5/15 [00:09<00:18,  1.89s/it]
# r
# [ 1.31455741]
# r
# [  3.56336659e-12]
# [[ -19.3551747 ]
#  [ -10.54725743]
#  [  12.22261703]
#  [ -88.68964243]
#  [  80.77295272]
#  [  -1.19498703]
#  [ -52.75270934]
#  [   3.10801744]
#  [  48.10364992]
#  [ 100.        ]
#  [  27.59832919]
#  [  64.4581032 ]
#  [-100.        ]
#  [ -71.01386807]
#  [ -66.42034859]
#  [ -36.64714863]
#  [ -32.18478593]]
#  40%|████      | 6/15 [00:11<00:17,  1.93s/it]
# r
# [  3.56336659e-12]
# r
# [ 0.83384517]
# [[ -19.3551747 ]
#  [ -10.54725743]
#  [  12.22261703]
#  [ -88.68964243]
#  [  80.77295272]
#  [  -1.19498703]
#  [ -52.75270934]
#  [   3.10801744]
#  [  48.10364992]
#  [ 100.        ]
#  [  27.59832919]
#  [  64.4581032 ]
#  [-100.        ]
#  [ -71.01386807]
#  [ -66.42034859]
#  [ -36.64714863]
#  [ -32.18478593]
#  [   0.61537841]
#  [ -80.12416223]]
#  47%|████▋     | 7/15 [00:13<00:16,  2.01s/it]
# r
# [ 0.83384517]
# r
# [ 0.82977413]
# [[ -19.3551747 ]
#  [ -10.54725743]
#  [  12.22261703]
#  [ -88.68964243]
#  [  80.77295272]
#  [  -1.19498703]
#  [ -52.75270934]
#  [   3.10801744]
#  [  48.10364992]
#  [ 100.        ]
#  [  27.59832919]
#  [  64.4581032 ]
#  [-100.        ]
#  [ -71.01386807]
#  [ -66.42034859]
#  [ -36.64714863]
#  [ -32.18478593]
#  [   0.61537841]
#  [ -80.12416223]
#  [  37.75440224]
#  [  39.95565288]]
#  53%|█████▎    | 8/15 [00:15<00:15,  2.15s/it]
# r
# [ 0.82977413]
# r
# [ 0.74506695]
# [[ -19.3551747 ]
#  [ -10.54725743]
#  [  12.22261703]
#  [ -88.68964243]
#  [  80.77295272]
#  [  -1.19498703]
#  [ -52.75270934]
#  [   3.10801744]
#  [  48.10364992]
#  [ 100.        ]
#  [  27.59832919]
#  [  64.4581032 ]
#  [-100.        ]
#  [ -71.01386807]
#  [ -66.42034859]
#  [ -36.64714863]
#  [ -32.18478593]
#  [   0.61537841]
#  [ -80.12416223]
#  [  37.75440224]
#  [  39.95565288]
#  [  90.31174711]
#  [  92.48579464]]
#  60%|██████    | 9/15 [00:18<00:13,  2.20s/it]
# r
# [ 0.74506695]
# r
# [ 0.79810145]
# [[ -19.3551747 ]
#  [ -10.54725743]
#  [  12.22261703]
#  [ -88.68964243]
#  [  80.77295272]
#  [  -1.19498703]
#  [ -52.75270934]
#  [   3.10801744]
#  [  48.10364992]
#  [ 100.        ]
#  [  27.59832919]
#  [  64.4581032 ]
#  [-100.        ]
#  [ -71.01386807]
#  [ -66.42034859]
#  [ -36.64714863]
#  [ -32.18478593]
#  [   0.61537841]
#  [ -80.12416223]
#  [  37.75440224]
#  [  39.95565288]
#  [  90.31174711]
#  [  92.48579464]
#  [  72.50194284]
#  [  56.43853613]]
#  67%|██████▋   | 10/15 [00:20<00:11,  2.22s/it]
# r
# [ 0.79810145]
# r
# [ 0.40761149]
# [[ -19.3551747 ]
#  [ -10.54725743]
#  [  12.22261703]
#  [ -88.68964243]
#  [  80.77295272]
#  [  -1.19498703]
#  [ -52.75270934]
#  [   3.10801744]
#  [  48.10364992]
#  [ 100.        ]
#  [  27.59832919]
#  [  64.4581032 ]
#  [-100.        ]
#  [ -71.01386807]
#  [ -66.42034859]
#  [ -36.64714863]
#  [ -32.18478593]
#  [   0.61537841]
#  [ -80.12416223]
#  [  37.75440224]
#  [  39.95565288]
#  [  90.31174711]
#  [  92.48579464]
#  [  72.50194284]
#  [  56.43853613]
#  [  20.33131773]
#  [ -44.96940007]]
#  73%|███████▎  | 11/15 [00:22<00:09,  2.25s/it]
# r
# [ 0.40761149]
# r
# [ 0.60490787]
# [[ -19.3551747 ]
#  [ -10.54725743]
#  [  12.22261703]
#  [ -88.68964243]
#  [  80.77295272]
#  [  -1.19498703]
#  [ -52.75270934]
#  [   3.10801744]
#  [  48.10364992]
#  [ 100.        ]
#  [  27.59832919]
#  [  64.4581032 ]
#  [-100.        ]
#  [ -71.01386807]
#  [ -66.42034859]
#  [ -36.64714863]
#  [ -32.18478593]
#  [   0.61537841]
#  [ -80.12416223]
#  [  37.75440224]
#  [  39.95565288]
#  [  90.31174711]
#  [  92.48579464]
#  [  72.50194284]
#  [  56.43853613]
#  [  20.33131773]
#  [ -44.96940007]
#  [   7.31041384]
#  [ -59.46190527]]
#  80%|████████  | 12/15 [00:25<00:06,  2.27s/it]
# r
# [ 0.60490787]
# r
# [ 0.84877672]
# [[ -19.3551747 ]
#  [ -10.54725743]
#  [  12.22261703]
#  [ -88.68964243]
#  [  80.77295272]
#  [  -1.19498703]
#  [ -52.75270934]
#  [   3.10801744]
#  [  48.10364992]
#  [ 100.        ]
#  [  27.59832919]
#  [  64.4581032 ]
#  [-100.        ]
#  [ -71.01386807]
#  [ -66.42034859]
#  [ -36.64714863]
#  [ -32.18478593]
#  [   0.61537841]
#  [ -80.12416223]
#  [  37.75440224]
#  [  39.95565288]
#  [  90.31174711]
#  [  92.48579464]
#  [  72.50194284]
#  [  56.43853613]
#  [  20.33131773]
#  [ -44.96940007]
#  [   7.31041384]
#  [ -59.46190527]
#  [ -14.63201581]
#  [ -25.81148027]]
#  87%|████████▋ | 13/15 [00:27<00:04,  2.36s/it]
# r
# [ 0.84877672]
# r
# [ 0.0864354]
# [[ -19.3551747 ]
#  [ -10.54725743]
#  [  12.22261703]
#  [ -88.68964243]
#  [  80.77295272]
#  [  -1.19498703]
#  [ -52.75270934]
#  [   3.10801744]
#  [  48.10364992]
#  [ 100.        ]
#  [  27.59832919]
#  [  64.4581032 ]
#  [-100.        ]
#  [ -71.01386807]
#  [ -66.42034859]
#  [ -36.64714863]
#  [ -32.18478593]
#  [   0.61537841]
#  [ -80.12416223]
#  [  37.75440224]
#  [  39.95565288]
#  [  90.31174711]
#  [  92.48579464]
#  [  72.50194284]
#  [  56.43853613]
#  [  20.33131773]
#  [ -44.96940007]
#  [   7.31041384]
#  [ -59.46190527]
#  [ -14.63201581]
#  [ -25.81148027]
#  [ -94.44480436]
#  [  -0.3394448 ]]
#  93%|█████████▎| 14/15 [00:30<00:02,  2.51s/it]
# r
# [ 0.0864354]
# r
# [ 0.37657646]
# [[ -19.3551747 ]
#  [ -10.54725743]
#  [  12.22261703]
#  [ -88.68964243]
#  [  80.77295272]
#  [  -1.19498703]
#  [ -52.75270934]
#  [   3.10801744]
#  [  48.10364992]
#  [ 100.        ]
#  [  27.59832919]
#  [  64.4581032 ]
#  [-100.        ]
#  [ -71.01386807]
#  [ -66.42034859]
#  [ -36.64714863]
#  [ -32.18478593]
#  [   0.61537841]
#  [ -80.12416223]
#  [  37.75440224]
#  [  39.95565288]
#  [  90.31174711]
#  [  92.48579464]
#  [  72.50194284]
#  [  56.43853613]
#  [  20.33131773]
#  [ -44.96940007]
#  [   7.31041384]
#  [ -59.46190527]
#  [ -14.63201581]
#  [ -25.81148027]
#  [ -94.44480436]
#  [  -0.3394448 ]
#  [  -4.9591187 ]
#  [  -5.44316855]]
# 100%|██████████| 15/15 [00:33<00:00,  2.60s/it]

# %%
myProblem.plot_convergence()
