# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2

from GPyOpt.methods import BayesianOptimization
import GPy
import GPyOpt
from numpy.random import seed
from tqdm import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# WARNING: pylab import has clobbered these variables: ['__version__']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
def myf(x):
    return -((x>0)*2-1)

bounds = [{'name': 'var_1', 'type': 'continuous', 'domain': (-100,100)}]
max_iter = 15

# %%
myProblem = BayesianOptimization(myf,bounds,acquisition_type="BinaryT",
#                                  initial_design_numdata=None,
                                 normalize_Y = True,
                                 batch_size = 2,
                                 evaluator_type='local_penalization')
# Out:
# <GPyOpt.acquisitions.LP.AcquisitionLP object at 0x11257d390>

# %%
from IPython.display import clear_output
myProblem.plot_acquisition()

for i in tqdm(range(15)):
    myProblem.run_optimization(max_iter=1) 
    myProblem.plot_acquisition_binaryT()
# Out:
# [[ 55.48083253]
#  [-72.21611527]
#  [-29.00296359]
#  [ -7.39065257]
#  [-69.7400733 ]]
#   0%|          | 0/15 [00:00<?, ?it/s]
# [[  55.48083253]
#  [ -72.21611527]
#  [ -29.00296359]
#  [  -7.39065257]
#  [ -69.7400733 ]
#  [   9.78346325]
#  [-100.        ]]
#   7%|▋         | 1/15 [00:02<00:38,  2.75s/it]
# [[  55.48083253]
#  [ -72.21611527]
#  [ -29.00296359]
#  [  -7.39065257]
#  [ -69.7400733 ]
#  [   9.78346325]
#  [-100.        ]
#  [ 100.        ]
#  [  97.42799787]]
#  13%|█▎        | 2/15 [00:05<00:35,  2.74s/it]
# [[  55.48083253]
#  [ -72.21611527]
#  [ -29.00296359]
#  [  -7.39065257]
#  [ -69.7400733 ]
#  [   9.78346325]
#  [-100.        ]
#  [ 100.        ]
#  [  97.42799787]
#  [   0.79552078]
#  [   1.58954831]]
#  20%|██        | 3/15 [00:08<00:32,  2.75s/it]
# [[  55.48083253]
#  [ -72.21611527]
#  [ -29.00296359]
#  [  -7.39065257]
#  [ -69.7400733 ]
#  [   9.78346325]
#  [-100.        ]
#  [ 100.        ]
#  [  97.42799787]
#  [   0.79552078]
#  [   1.58954831]
#  [ -45.65358677]
#  [ -46.20497918]]
#  27%|██▋       | 4/15 [00:10<00:30,  2.75s/it]
# [[  55.48083253]
#  [ -72.21611527]
#  [ -29.00296359]
#  [  -7.39065257]
#  [ -69.7400733 ]
#  [   9.78346325]
#  [-100.        ]
#  [ 100.        ]
#  [  97.42799787]
#  [   0.79552078]
#  [   1.58954831]
#  [ -45.65358677]
#  [ -46.20497918]
#  [  34.3078387 ]
#  [  33.71343707]]
#  33%|███▎      | 5/15 [00:13<00:27,  2.77s/it]
# [[  55.48083253]
#  [ -72.21611527]
#  [ -29.00296359]
#  [  -7.39065257]
#  [ -69.7400733 ]
#  [   9.78346325]
#  [-100.        ]
#  [ 100.        ]
#  [  97.42799787]
#  [   0.79552078]
#  [   1.58954831]
#  [ -45.65358677]
#  [ -46.20497918]
#  [  34.3078387 ]
#  [  33.71343707]
#  [  75.27028232]
#  [  74.70911672]]
#  40%|████      | 6/15 [00:16<00:25,  2.81s/it]
# [[  55.48083253]
#  [ -72.21611527]
#  [ -29.00296359]
#  [  -7.39065257]
#  [ -69.7400733 ]
#  [   9.78346325]
#  [-100.        ]
#  [ 100.        ]
#  [  97.42799787]
#  [   0.79552078]
#  [   1.58954831]
#  [ -45.65358677]
#  [ -46.20497918]
#  [  34.3078387 ]
#  [  33.71343707]
#  [  75.27028232]
#  [  74.70911672]
#  [  -3.51743802]
#  [  -3.65026069]]
#  47%|████▋     | 7/15 [00:20<00:23,  2.97s/it]
# [[  55.48083253]
#  [ -72.21611527]
#  [ -29.00296359]
#  [  -7.39065257]
#  [ -69.7400733 ]
#  [   9.78346325]
#  [-100.        ]
#  [ 100.        ]
#  [  97.42799787]
#  [   0.79552078]
#  [   1.58954831]
#  [ -45.65358677]
#  [ -46.20497918]
#  [  34.3078387 ]
#  [  33.71343707]
#  [  75.27028232]
#  [  74.70911672]
#  [  -3.51743802]
#  [  -3.65026069]
#  [ -87.81414393]
#  [ -87.59418156]]
#  53%|█████▎    | 8/15 [00:23<00:20,  2.97s/it]
# [[  55.48083253]
#  [ -72.21611527]
#  [ -29.00296359]
#  [  -7.39065257]
#  [ -69.7400733 ]
#  [   9.78346325]
#  [-100.        ]
#  [ 100.        ]
#  [  97.42799787]
#  [   0.79552078]
#  [   1.58954831]
#  [ -45.65358677]
#  [ -46.20497918]
#  [  34.3078387 ]
#  [  33.71343707]
#  [  75.27028232]
#  [  74.70911672]
#  [  -3.51743802]
#  [  -3.65026069]
#  [ -87.81414393]
#  [ -87.59418156]
#  [ -18.8490256 ]
#  [ -18.67446871]]
#  60%|██████    | 9/15 [00:25<00:17,  2.94s/it]
# [[  55.48083253]
#  [ -72.21611527]
#  [ -29.00296359]
#  [  -7.39065257]
#  [ -69.7400733 ]
#  [   9.78346325]
#  [-100.        ]
#  [ 100.        ]
#  [  97.42799787]
#  [   0.79552078]
#  [   1.58954831]
#  [ -45.65358677]
#  [ -46.20497918]
#  [  34.3078387 ]
#  [  33.71343707]
#  [  75.27028232]
#  [  74.70911672]
#  [  -3.51743802]
#  [  -3.65026069]
#  [ -87.81414393]
#  [ -87.59418156]
#  [ -18.8490256 ]
#  [ -18.67446871]
#  [ -58.21847899]
#  [ -58.28296292]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-be526681de39> in <module>()
#       4 for i in tqdm(range(15)):
#       5     myProblem.run_optimization(max_iter=1)
# ----> 6     myProblem.plot_acquisition_binaryT()
#
# /Users/Chengyu/GitHub/GPyOpt/GPyOpt/core/bo.py in plot_acquisition_binaryT(self, filename)
#     243                                         self.acquisition.acquisition_function,
#     244                                         self.suggested_sample,
# --> 245                                         filename)
#     246
#     247     def plot_convergence(self,filename=None):
#
# /Users/Chengyu/GitHub/GPyOpt/GPyOpt/plotting/plots_bo.py in plot_acquisition_binaryT(bounds, input_dim, model, Xdata, Ydata, acquisition_function, suggested_sample, filename)
#     160         acqu = acquisition_function(x_grid)
#     161         acqu_normalized = (-acqu - min(-acqu))/(max(-acqu - min(-acqu)))
# --> 162         m, v = model.predict(x_grid)
#     163         model.plot_density(bounds[0], alpha=.5)
#     164
#
# /Users/Chengyu/.local/lib/python3.5/site-packages/GPy/core/gp.py in predict(self, Xnew, full_cov, Y_metadata, kern, likelihood, include_likelihood)
#     249         """
#     250         #predict the latent function values
# --> 251         mu, var = self._raw_predict(Xnew, full_cov=full_cov, kern=kern)
#     252
#     253         if include_likelihood:
#
# /Users/Chengyu/.local/lib/python3.5/site-packages/GPy/core/gp.py in _raw_predict(self, Xnew, full_cov, kern)
#     216             \Sigma := \texttt{Likelihood.variance / Approximate likelihood covariance}
#     217         """
# --> 218         mu, var = self.posterior._raw_predict(kern=self.kern if kern is None else kern, Xnew=Xnew, pred_var=self._predictive_variable, full_cov=full_cov)
#     219         if self.mean_function is not None:
#     220             mu += self.mean_function.f(Xnew)
#
# /Users/Chengyu/.local/lib/python3.5/site-packages/GPy/inference/latent_function_inference/posterior.py in _raw_predict(self, kern, Xnew, pred_var, full_cov)
#     262             Kxx = kern.Kdiag(Xnew)
#     263             if self._woodbury_chol.ndim == 2:
# --> 264                 tmp = dtrtrs(self._woodbury_chol, Kx)[0]
#     265                 var = (Kxx - np.square(tmp).sum(0))[:,None]
#     266             elif self._woodbury_chol.ndim == 3: # Missing data
#
# /Users/Chengyu/.local/lib/python3.5/site-packages/GPy/util/linalg.py in dtrtrs(A, B, lower, trans, unitdiag)
#     113     A = np.asfortranarray(A)
#     114     #Note: B does not seem to need to be F ordered!
# --> 115     return lapack.dtrtrs(A, B, lower=lower, trans=trans, unitdiag=unitdiag)
#     116
#     117 def dpotrs(A, B, lower=1):
#
# KeyboardInterrupt:

# %%
myProblem.plot_convergence()
